# %% [markdown]
# # Test Image Classifier

# %%
from img_classification import *

# %%
results = classify_image("dog.jpg")
print(results["label"])
print(results["confidence"])
# Out:
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# golden retriever
# 0.8912700414657593

# %% [markdown]
# # Test Features Extraction

# %%
from feature_extraction import *

# %%
tensor = extract_features("dog.jpg")

# %%
tensor.size()
# Out:
# torch.Size([401408])

# %% [markdown]
# # Add noise and reconstruct

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from generate_adversarial import *
# Out:
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# c:\Users\Hugo\Documents\deep_learning\adversarial_noise\generate_adversarial.py:40: UserWarning: Using a target size (torch.Size([512])) that is different to the input size (torch.Size([1, 512, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   loss_embed_desired_label = torch.nn.functional.mse_loss(features, target_features)
# Step 0, Loss: 1.4735
# Step 10, Loss: 1.1684
# Step 20, Loss: 1.1444
# Step 30, Loss: 1.1360
# Step 40, Loss: 1.1319
# Step 50, Loss: 1.1292
# Step 60, Loss: 1.1282
# Step 70, Loss: 1.1266
# Step 80, Loss: 1.1259
# Step 90, Loss: 1.1253
# Step 100, Loss: 1.1247
# Step 110, Loss: 1.1243
# Step 120, Loss: 1.1234
# Step 130, Loss: 1.1229
# Step 140, Loss: 1.1226
# Step 150, Loss: 1.1225
# Step 160, Loss: 1.1220
# Step 170, Loss: 1.1224
# Step 180, Loss: 1.1213
# Step 190, Loss: 1.1218
# dog label: golden retriever confidence: 0.8912700414657593
# lion label: lion confidence: 0.9992941617965698
# advers label: English setter confidence: 0.08539476990699768

# %%
advers_image = generate_adversarial("dog.jpg", None)

plt.imshow(advers_image)
plt.show()
# Out:
# Step 0, Loss: 1.4735
# Step 10, Loss: 1.1685
# Step 20, Loss: 1.1448
# Step 30, Loss: 1.1356
# Step 40, Loss: 1.1313
# Step 50, Loss: 1.1284
# Step 60, Loss: 1.1268
# Step 70, Loss: 1.1258
# Step 80, Loss: 1.1255
# Step 90, Loss: 1.1249
# Step 100, Loss: 1.1232
# Step 110, Loss: 1.1228
# Step 120, Loss: 1.1224
# Step 130, Loss: 1.1219
# Step 140, Loss: 1.1215
# Step 150, Loss: 1.1208
# Step 160, Loss: 1.1209
# Step 170, Loss: 1.1204
# Step 180, Loss: 1.1207
# Step 190, Loss: 1.1200

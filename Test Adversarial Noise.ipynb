# %% [markdown]
# # Test Image Classifier

# %%
from img_classification import *

# %%
results = classify_image("dog.jpg")
print(results["label"])
print(results["confidence"])
# Out:
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# golden retriever
# 0.8912700414657593

# %% [markdown]
# # Test Features Extraction

# %%
from feature_extraction import *

# %%
tensor = extract_features("dog.jpg")

# %%
tensor.size()
# Out:
# torch.Size([401408])

# %% [markdown]
# # Add noise and reconstruct

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from generate_adversarial import *
# Out:
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# centroid path to be open: dining table/dining table_centroid.pkl
# selected class: dining table, index: 532
# Step 0, Loss: 96.3838
# c:\Users\Hugo\Documents\deep_learning\adversarial_noise\generate_adversarial.py:49: UserWarning: Using a target size (torch.Size([1, 25088])) that is different to the input size (torch.Size([1, 512, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   loss_embed_desired_label = torch.nn.functional.mse_loss(features, target_features)
# Step 10, Loss: 5.3012
# Step 20, Loss: 4.8003
# Step 30, Loss: 4.6920
# Step 40, Loss: 4.6194
# Step 50, Loss: 4.5612
# Step 60, Loss: 4.5126
# Step 70, Loss: 4.4745
# Step 80, Loss: 4.4483
# Step 90, Loss: 4.4285
# Step 100, Loss: 4.4134
# Step 110, Loss: 4.4001
# Step 120, Loss: 4.3887
# Step 130, Loss: 4.3791
# Step 140, Loss: 4.3708
# Step 150, Loss: 4.3633
# Step 160, Loss: 4.3560
# Step 170, Loss: 4.3500
# Step 180, Loss: 4.3446
# Step 190, Loss: 4.3396
# Step 200, Loss: 4.3354
# Step 210, Loss: 4.3315
# Step 220, Loss: 4.3276
# Step 230, Loss: 4.3241
# Step 240, Loss: 4.3210
# Step 250, Loss: 4.3183
# Step 260, Loss: 4.3159
# Step 270, Loss: 4.3138
# Step 280, Loss: 4.3120
# Step 290, Loss: 4.3102
# Step 300, Loss: 4.3084
# Step 310, Loss: 4.3067
# Step 320, Loss: 4.3051
# Step 330, Loss: 4.3036
# Step 340, Loss: 4.3022
# Step 350, Loss: 4.3010
# Step 360, Loss: 4.2998
# Step 370, Loss: 4.2987
# Step 380, Loss: 4.2975
# Step 390, Loss: 4.2964
# Step 400, Loss: 4.2954
# Step 410, Loss: 4.2944
# Step 420, Loss: 4.2934
# Step 430, Loss: 4.2925
# Step 440, Loss: 4.2916
# Step 450, Loss: 4.2908
# Step 460, Loss: 4.2900
# Step 470, Loss: 4.2892
# Step 480, Loss: 4.2885
# Step 490, Loss: 4.2877
# dog label: golden retriever confidence: 0.9161115288734436
# lion label: lion confidence: 0.9995193481445312
# advers label: dining table confidence: 0.9373831152915955

# %%
print(advers_res["probabilities"][532])
print(dog_res["probabilities"][532])
# Out:
# tensor(2.1320e-05, device='cuda:0')
# tensor(0.9796, device='cuda:0')

# %%
advers_res["probabilities"].argmax()
# Out:
# tensor(532, device='cuda:0')

# %%
input_path = "dog.jpg"
plt.imshow(Image.open(input_path).convert("RGB"))
plt.show()
input_res = classify_image(input_path)
advers_img = generate_adversarial(input_path, "dining table")
# advers_res = classify_image(Image.fromarray(advers_img), True)
advers_res = classify_image(advers_img, True)
plt.imshow(advers_img)
plt.show()
print("input", "label:", dog_res["label"], "confidence:", dog_res["confidence"])
print("advers", "label:", advers_res["label"], "confidence:", advers_res["confidence"])

advers_img = generate_adversarial(input_path, "folding chair")
# advers_res = classify_image(Image.fromarray(advers_img), True)
advers_res = classify_image(advers_img, True)
plt.imshow(advers_img)
plt.show()
print("input", "label:", dog_res["label"], "confidence:", dog_res["confidence"])
print("advers", "label:", advers_res["label"], "confidence:", advers_res["confidence"])
# Out:
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# centroid path to be open: dining table/dining table_centroid.pkl
# selected class: dining table, index: 532
# Step 0, Loss: 96.3838
# c:\Users\Hugo\Documents\deep_learning\adversarial_noise\generate_adversarial.py:49: UserWarning: Using a target size (torch.Size([1, 25088])) that is different to the input size (torch.Size([1, 512, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   loss_embed_desired_label = torch.nn.functional.mse_loss(features, target_features)
# Step 10, Loss: 5.2757
# Step 20, Loss: 4.7983
# Step 30, Loss: 4.6919
# Step 40, Loss: 4.6134
# Step 50, Loss: 4.5552
# Step 60, Loss: 4.5106
# Step 70, Loss: 4.4749
# Step 80, Loss: 4.4481
# Step 90, Loss: 4.4267
# Step 100, Loss: 4.4087
# Step 110, Loss: 4.3941
# Step 120, Loss: 4.3826
# Step 130, Loss: 4.3733
# Step 140, Loss: 4.3654
# Step 150, Loss: 4.3585
# Step 160, Loss: 4.3525
# Step 170, Loss: 4.3472
# Step 180, Loss: 4.3425
# Step 190, Loss: 4.3381
# Step 200, Loss: 4.3340
# Step 210, Loss: 4.3301
# Step 220, Loss: 4.3266
# Step 230, Loss: 4.3235
# Step 240, Loss: 4.3206
# Step 250, Loss: 4.3178
# Step 260, Loss: 4.3151
# Step 270, Loss: 4.3127
# Step 280, Loss: 4.3105
# Step 290, Loss: 4.3085
# Step 300, Loss: 4.3066
# Step 310, Loss: 4.3049
# Step 320, Loss: 4.3033
# Step 330, Loss: 4.3017
# Step 340, Loss: 4.3002
# Step 350, Loss: 4.2987
# Step 360, Loss: 4.2973
# Step 370, Loss: 4.2960
# Step 380, Loss: 4.2948
# Step 390, Loss: 4.2938
# Step 400, Loss: 4.2928
# Step 410, Loss: 4.2918
# Step 420, Loss: 4.2909
# Step 430, Loss: 4.2900
# Step 440, Loss: 4.2891
# Step 450, Loss: 4.2882
# Step 460, Loss: 4.2873
# Step 470, Loss: 4.2865
# Step 480, Loss: 4.2858
# Step 490, Loss: 4.2851
# input label: dining table confidence: 0.9892424941062927
# advers label: dining table confidence: 0.9325448870658875

# %%
advers_image = generate_adversarial("dog.jpg", None)

plt.imshow(advers_image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 advers_image = generate_adversarial("dog.jpg", None)
#       3 plt.imshow(advers_image)
#       4 plt.show()
#
# NameError: name 'generate_adversarial' is not defined

# %% [markdown]
# # Extract features centroids

# %%
from features_centroid_extraction import *

# %%
process_label_folder("folding chair")
# Out:
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Saved centroid for folding chair to folding chair\folding chair_centroid.pkl
# Centroid shape: (25088,)
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

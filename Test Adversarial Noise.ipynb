# %% [markdown]
# # Test Image Classifier

# %%
from img_classification import *

# %%
results = classify_image("dog.jpg")
print(results["label"])
print(results["confidence"])
# Out:
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# golden retriever
# 0.8912700414657593

# %% [markdown]
# # Test Features Extraction

# %%
from feature_extraction import *

# %%
tensor = extract_features("dog.jpg")
# Out:
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
tensor.size()
# Out:
# torch.Size([401408])

# %% [markdown]
# # Add noise and reconstruct

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from generate_adversarial import *

# %%
advers_image = generate_adversarial("dog.jpg", None)

plt.imshow(advers_image)
plt.show()
# Out:
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# c:\Users\Hugo\Documents\deep_learning\adversarial_noise\generate_adversarial.py:35: UserWarning: Using a target size (torch.Size([1, 512])) that is different to the input size (torch.Size([1, 512, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   loss_embed_desired_label = torch.nn.functional.mse_loss(features, target_features.unsqueeze(0))
# Step 0, Loss: 2.1286
# Step 10, Loss: 1.4301
# Step 20, Loss: 1.4163
# Step 30, Loss: 1.4110
# Step 40, Loss: 1.4080
# Step 50, Loss: 1.4062
# Step 60, Loss: 1.4050
# Step 70, Loss: 1.4041
# Step 80, Loss: 1.4036
# Step 90, Loss: 1.4031

# %% [markdown]
# # Test Image Classifier

# %%
from img_classification import *

# %%
results = classify_image("dog.jpg")
print(results["label"])
print(results["confidence"])
# Out:
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# golden retriever
# 0.8912700414657593

# %% [markdown]
# # Test Features Extraction

# %%
from feature_extraction import *

# %%
tensor = extract_features("dog.jpg")

# %%
tensor.size()
# Out:
# torch.Size([401408])

# %% [markdown]
# # Add noise and reconstruct

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from generate_adversarial import *

# %%
input_path = "dog.jpg"
real_input_label = "dog"
# uncomment following lines for an example that doesn't work, optimiser cannot modify image to match desired label 
# UPDATE: it does work with a very high epsilon value and a high number of steps, similarity still not great
# input_path = "folding chair/images/folding_chair_1.jpg"
# real_input_label = "folding chair"
plt.imshow(Image.open(input_path).convert("RGB"))
plt.show()
input_res = classify_image(input_path)
advers_img = generate_adversarial(input_path, "dining table", steps=100, epsilon=0.05)
# advers_res = classify_image(Image.fromarray(advers_img), True)
advers_res = classify_image(advers_img, True)
plt.imshow(advers_img)
plt.show()
print("input", "real label:", {real_input_label}, "predicted label for input no adversarial noise:", input_res["label"], "confidence: ", input_res["confidence"])
print("advers", "label:", advers_res["label"], "confidence:", advers_res["confidence"])

advers_img = generate_and_save_adversarial(input_path, "folding chair", "output_advers_folding_chair.jpg", steps=200)
# advers_res = classify_image(Image.fromarray(advers_img), True)
advers_res = classify_image(advers_img, True)
plt.imshow(advers_img)
plt.show()
print("input", "real label:", {real_input_label}, "predicted label for input no adversarial noise:", input_res["label"], "confidence: ", input_res["confidence"])
print("advers", "label:", advers_res["label"], "confidence:", advers_res["confidence"])
# Out:
# centroid path to be open: dining table/dining table_centroid.pkl
# selected class: dining table, index: 532
# Step 0, Loss: 96.3838
# Step 10, Loss: 4.9179
# Step 20, Loss: 4.7418
# Step 30, Loss: 4.6478
# Step 40, Loss: 4.5732
# Step 50, Loss: 4.5136
# Step 60, Loss: 4.4647
# Step 70, Loss: 4.4255
# Step 80, Loss: 4.3918
# Step 90, Loss: 4.3646
# input real label: {'dog'} predicted label for input no adversarial noise: golden retriever confidence:  0.9161115288734436
# advers label: dining table confidence: 0.984418511390686
# centroid path to be open: folding chair/folding chair_centroid.pkl
# selected class: folding chair, index: 559
# Step 0, Loss: 73.0740
# Step 10, Loss: 10.2766
# Step 20, Loss: 8.5126
# Step 30, Loss: 8.3641
# Step 40, Loss: 8.2894
# Step 50, Loss: 8.2284
# Step 60, Loss: 8.1748
# Step 70, Loss: 8.1363
# Step 80, Loss: 8.1074
# Step 90, Loss: 8.0831
# Step 100, Loss: 8.0634
# Step 110, Loss: 8.0477
# Step 120, Loss: 8.0354
# Step 130, Loss: 8.0254
# ...

# %% [markdown]
# # Extract features centroids

# %%
from features_centroid_extraction import *

# %%
process_label_folder("folding chair")
# Out:
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Saved centroid for folding chair to folding chair\folding chair_centroid.pkl
# Centroid shape: (25088,)
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)
